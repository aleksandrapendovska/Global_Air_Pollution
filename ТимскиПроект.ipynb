# %% [markdown]
# #1. Анализа на глобалното загадување на воздухот во различни земји

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/Тимски Проект /global air pollution dataset.csv')
df
# Out:
#                         Country              City  AQI Value AQI Category  \
# 0            Russian Federation        Praskoveya         51     Moderate
# 1                        Brazil  Presidente Dutra         41         Good
# 2                         Italy   Priolo Gargallo         66     Moderate
# 3                        Poland         Przasnysz         34         Good
# 4                        France          Punaauia         22         Good
# ...                         ...               ...        ...          ...
# 23458                     India      Gursahaiganj        184    Unhealthy
# 23459                    France            Sceaux         50         Good
# 23460                     India          Mormugao         50         Good
# 23461  United States of America       Westerville         71     Moderate
# 23462                  Malaysia            Marang         70     Moderate
#
#        CO AQI Value CO AQI Category  Ozone AQI Value Ozone AQI Category  \
# ...

# %%
df.info() #информации за датасетот
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23463 entries, 0 to 23462
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             23036 non-null  object
#  1   City                23462 non-null  object
#  2   AQI Value           23463 non-null  int64
#  3   AQI Category        23463 non-null  object
#  4   CO AQI Value        23463 non-null  int64
#  5   CO AQI Category     23463 non-null  object
#  6   Ozone AQI Value     23463 non-null  int64
#  7   Ozone AQI Category  23463 non-null  object
#  8   NO2 AQI Value       23463 non-null  int64
#  9   NO2 AQI Category    23463 non-null  object
#  10  PM2.5 AQI Value     23463 non-null  int64
#  11  PM2.5 AQI Category  23463 non-null  object
# dtypes: int64(5), object(7)
# memory usage: 2.1+ MB

# %%
df['AQI Category'].value_counts() #категории на AQI
# Out:
# AQI Category
# Good                              9936
# Moderate                          9231
# Unhealthy                         2227
# Unhealthy for Sensitive Groups    1591
# Very Unhealthy                     287
# Hazardous                          191
# Name: count, dtype: int64

# %%
df['AQI Category'].value_counts().plot.bar()
plt.title('AQI Category')
plt.show()

# %% [markdown]
# *   Good -   < 50
# *   Moderate -  51-100
# *   Unhealthy - 101-150
# *   Unhealthy for sensitive groups -  101-150
# *   Very unhealthy -  151-200
# *   Hazardous -  >200
#
#
#
# *   9936 градови имаат добар квалитет на воздух
# *   2227 имаат лош квалитет на воздух
# *   286 имаат многу лош, додека пак 191 имаат опасен квалитет на воздух.

# %%
hazardous_AQI = df[df['AQI Value'] >300]
hazardous_AQI
# Out:
#             Country          City  AQI Value AQI Category  CO AQI Value  \
# 180           India    Govindgarh        307    Hazardous             1
# 276        Pakistan  Bahawalnagar        500    Hazardous             1
# 277    South Africa       Balfour        380    Hazardous            31
# 417           India      Phillaur        444    Hazardous             2
# 439           India         Salon        303    Hazardous             1
# ...             ...           ...        ...          ...           ...
# 22560         India      Miranpur        464    Hazardous             4
# 22577         India        Bahjoi        500    Hazardous             1
# 22824         India        Bilari        500    Hazardous             4
# 22842         India  Sikandarabad        500    Hazardous             2
# 23201        Mexico  Tlalancaleca        355    Hazardous             4
#
#       CO AQI Category  Ozone AQI Value              Ozone AQI Category  \
# ...

# %%
hazardous_AQI['Country'].value_counts()
# Out:
# Country
# India                               158
# Pakistan                             13
# Mexico                                6
# South Africa                          3
# China                                 3
# Democratic Republic of the Congo      3
# Republic of Korea                     1
# United States of America              1
# Chile                                 1
# Russian Federation                    1
# Name: count, dtype: int64

# %%
hazardous_AQI['Country'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Country'>

# %% [markdown]
# Од 190 градови, 158 се во Индија, 13 во Пакистан, 6 во Мексико и останатите се во Јужна Африка, Конго, Кореја, Кина, Чиле, Америка и Русија.

# %%
good_AQI=df[df['AQI Value'] <=50]
good_AQI['Country'].value_counts()
# Out:
# Country
# Brazil                      1125
# Russian Federation          1025
# United States of America    1001
# Germany                      717
# Japan                        432
#                             ...
# Dominican Republic             1
# Jamaica                        1
# Senegal                        1
# Solomon Islands                1
# Belize                         1
# Name: count, Length: 139, dtype: int64

# %%
good_AQI['Country'].value_counts().head(10).plot.bar()
plt.title('Country with Good Air Quality')
plt.ylabel('No.of cities')
plt.show()

# %% [markdown]
# Повеќето градови со добар квалитет воздух се во Бразил.
# 1125 градови во Бразил имаат добар квалитет на воздухот.
# Русија е втора земја со добар квалитет на воздухот.
# САД, Германија се на третото и четвртото место.

# %%
df[df['PM2.5 AQI Value']>100]
# Out:
#                                   Country           City  AQI Value  \
# 9                                   Egypt         Qalyub        142
# 12                                  India         Radaur        158
# 13                               Pakistan         Radhan        158
# 16                                  India         Rajgir        154
# 19                                  India      Phulabani        161
# ...                                   ...            ...        ...
# 23429                              Mexico    Tlaltelulco        181
# 23436                             Nigeria        Hadejia        141
# 23439  Venezuela (Bolivarian Republic of)  Villa De Cura        131
# 23449                               China       Wangqing        101
# 23458                               India   Gursahaiganj        184
#
#                          AQI Category  CO AQI Value CO AQI Category  \
# 9      Unhealthy for Sensitive Groups             3            Good
# ...

# %%
df['PM2.5 AQI Category'].value_counts()
# Out:
# PM2.5 AQI Category
# Good                              10208
# Moderate                           9075
# Unhealthy                          2129
# Unhealthy for Sensitive Groups     1624
# Very Unhealthy                      255
# Hazardous                           172
# Name: count, dtype: int64

# %%
df['PM2.5 AQI Category'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='PM2.5 AQI Category'>

# %% [markdown]
# поголемиот дел од градoвите имаат добра вредност на PM2.5 AQI (9950 градови)
# 8939 градови имаат умерена вредност на PM2,5 AQI и 172 градови имаат огромна вредност на PM2,5 AQI.

# %%
pollutants = ['CO AQI Value', 'Ozone AQI Value', 'NO2 AQI Value', 'PM2.5 AQI Value']
aqi_values = df['AQI Value']

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 10))

for i, ax in enumerate(axes.flat):
    ax.scatter(df[pollutants[i]], aqi_values, alpha=0.5)
    ax.set_xlabel(pollutants[i])
    ax.set_ylabel('AQI Value')
    ax.set_title(f'{pollutants[i]} vs AQI Value')

plt.tight_layout()
plt.show()

# %% [markdown]
# #2. Предвидување на глобалното загадување на воздухот во различни земји

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/Тимски Проект /global air pollution dataset.csv')

# %%
df
# Out:
#                         Country              City  AQI Value AQI Category  \
# 0            Russian Federation        Praskoveya         51     Moderate
# 1                        Brazil  Presidente Dutra         41         Good
# 2                         Italy   Priolo Gargallo         66     Moderate
# 3                        Poland         Przasnysz         34         Good
# 4                        France          Punaauia         22         Good
# ...                         ...               ...        ...          ...
# 23458                     India      Gursahaiganj        184    Unhealthy
# 23459                    France            Sceaux         50         Good
# 23460                     India          Mormugao         50         Good
# 23461  United States of America       Westerville         71     Moderate
# 23462                  Malaysia            Marang         70     Moderate
#
#        CO AQI Value CO AQI Category  Ozone AQI Value Ozone AQI Category  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
df['AQI Category'] = le.fit_transform(df['AQI Category'])

# %%
df['AQI Category'].value_counts()
# Out:
# AQI Category
# 0    9936
# 2    9231
# 3    2227
# 4    1591
# 5     287
# 1     191
# Name: count, dtype: int64

# %%
df
# Out:
#                         Country              City  AQI Value  AQI Category  \
# 0            Russian Federation        Praskoveya         51             2
# 1                        Brazil  Presidente Dutra         41             0
# 2                         Italy   Priolo Gargallo         66             2
# 3                        Poland         Przasnysz         34             0
# 4                        France          Punaauia         22             0
# ...                         ...               ...        ...           ...
# 23458                     India      Gursahaiganj        184             3
# 23459                    France            Sceaux         50             0
# 23460                     India          Mormugao         50             0
# 23461  United States of America       Westerville         71             2
# 23462                  Malaysia            Marang         70             2
#
# ...

# %%
df.isnull().sum()
# Out:
# Country               427
# City                    1
# AQI Value               0
# AQI Category            0
# CO AQI Value            0
# CO AQI Category         0
# Ozone AQI Value         0
# Ozone AQI Category      0
# NO2 AQI Value           0
# NO2 AQI Category        0
# PM2.5 AQI Value         0
# PM2.5 AQI Category      0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
x = df.drop(['Country', 'City', 'AQI Category', 'CO AQI Category', 'Ozone AQI Category', 'NO2 AQI Category', 'PM2.5 AQI Category'], axis = 1)

# %%
x
# Out:
#        AQI Value  CO AQI Value  Ozone AQI Value  NO2 AQI Value  \
# 0             51             1               36              0
# 1             41             1                5              1
# 2             66             1               39              2
# 3             34             1               34              0
# 4             22             0               22              0
# ...          ...           ...              ...            ...
# 23458        184             3              154              2
# 23459         50             1               20              5
# 23460         50             1               22              1
# 23461         71             1               44              2
# 23462         70             1               38              0
#
#        PM2.5 AQI Value
# 0                   51
# 1                   41
# 2                   66
# 3                   20
# 4                    6
# ...                ...
# 23458              184
# ...

# %%
y = df.iloc[:, 3:4]

# %%
y
# Out:
#        AQI Category
# 0                 2
# 1                 0
# 2                 2
# 3                 0
# 4                 0
# ...             ...
# 23458             3
# 23459             0
# 23460             0
# 23461             2
# 23462             2
#
# [23035 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# %%
x = scaler.fit_transform(x)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

classifier = DecisionTreeClassifier(max_depth=3)
classifier = classifier.fit(x_train,y_train)

y_pred = classifier.predict(x_test)

# %%
from sklearn import metrics

print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.977859778597786

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1926
#            1       0.00      0.00      0.00        45
#            2       1.00      1.00      1.00      1841
#            3       0.80      1.00      0.89       405
#            4       1.00      1.00      1.00       333
#            5       0.00      0.00      0.00        57
#
#     accuracy                           0.98      4607
#    macro avg       0.63      0.67      0.65      4607
# weighted avg       0.96      0.98      0.97      4607
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
df_pred = pd.DataFrame(y_pred)

# %%
df_pred.columns = ['AQI Category Predictions']

# %%
df_pred
# Out:
#       AQI Category Predictions
# 0                            4
# 1                            3
# 2                            0
# 3                            2
# 4                            2
# ...                        ...
# 4602                         2
# 4603                         3
# 4604                         0
# 4605                         2
# 4606                         0
#
# [4607 rows x 1 columns]

# %%
category_mapping = {0: 'Good', 1: 'Hazardous', 2: 'Moderate', 3: 'Unhealthy', 4: 'Unhealthy for Sensitive Groups', 5: 'Very Unhealthy'}

# %%
df_pred['AQI Category Predictions'] = df_pred['AQI Category Predictions'].map(category_mapping)

# %%
df_pred
# Out:
#             AQI Category Predictions
# 0     Unhealthy for Sensitive Groups
# 1                          Unhealthy
# 2                               Good
# 3                           Moderate
# 4                           Moderate
# ...                              ...
# 4602                        Moderate
# 4603                       Unhealthy
# 4604                            Good
# 4605                        Moderate
# 4606                            Good
#
# [4607 rows x 1 columns]

# %%
df_pred['AQI Category Predictions'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='AQI Category Predictions'>
